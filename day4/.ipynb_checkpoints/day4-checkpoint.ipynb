# %% [markdown]
# # Exersices for Day 4
# Testing and documentation of code, plotting with matplotlib.
# ## 1. Testing code with `py.test`
# ### a. Install `pytest` using e.g.
# ```
# pip install pytest --user
# ```
# ### b. Write a module `test_simple_math.py` which test the correctness of the math operations inside `simple_math.py`.
# You can run the tests using the `py.test`command. Note that the name of your test function should start with `test_`.

# %% [markdown]
# ## 2. Documenting code
# ### a. Write some meaningful docstrings for the `simple_math.py`module, e.g. following the [numpy_doc](https://numpydoc.readthedocs.io/en/latest/format.html) standard.

# %%
import simple_math

# %%
simple_math.simple_add(3, 4)
# Out:
# 7
